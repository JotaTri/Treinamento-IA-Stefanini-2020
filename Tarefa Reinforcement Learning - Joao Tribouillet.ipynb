# %% [markdown]
# # Tarefa
# __________
# Resolver o problema do rato utilizando Q-Table. Você deve programar o ambiente e o algoritmo de Reinforcement Learning.
#
# ![Rato](https://i.imgur.com/rYnjoet.png)
#
# Sobre o ambiente:
#   * O episódio deve terminar quando o rato alcançar a pilha de queijos ou tomar o veneno.
#   * O objetivo é fazer com que o rato pegue todos os queijos do mapa sem tomar o veneno.
#   * As ações devem ser mover o rato, em 1 casa, para cima, baixo, esquerda e direita.
#   * O rato está confinado no espaço de 6 casas, conforme a imagem abaixo.
#
# Dicas:
#   * É possível completar toda a tarefa utilizando apenas numpy.
#   * Ler sobre Q-Learning na referência \[1\].
#   * Representar o mapa como uma matriz.
#
# Tabela Q sugerida:
#
# ![Q-Table](https://i.imgur.com/MWWvHZl.png)
#
# Referências:
#
# 1. PALANISAMY, Praveen. Hands-On Intelligent Agents with OpenAI Gym: Your guide to   developing AI agents using deep reinforcement learning. Packt Publishing Ltd, 2018.

# %% [markdown]
# # Entrega
# ___________
#
# Prazo: **26/02**
#
# Enviar para **lbpires@latam.stefanini.com**

# %% [markdown]
# # Código
# ____
#
# ### Parâmetros

# %%
class TrainingParameters:
    def __init__(self, max_episodes: int, steps_per_episode: int):  
        self.max_episodes = int(max_episodes)
        self.steps_per_episode = int(steps_per_episode)


class AgentParameters:
    def __init__(self, epsilon_min, epsilon_decay, start_epsilon):
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.start_epsilon = start_epsilon


class LearningParameters:
    def __init__(self, alpha, gamma):
        self.alpha = alpha
        self.gamma = gamma

# %% [markdown]
# ### Q-Table

# %%
import numpy as np

class QTable:
    def __init__(self, num_states: int, num_actions: int, params: LearningParameters):
        self.table = np.random.rand(num_states, num_actions)
        self.gamma = params.gamma
        self.alpha = params.alpha

    # calculates Q-table values
    def learn(self, obs, action_index, reward, next_obs):
        deltaQ = reward + self.gamma*np.max(self.table[next_obs]) - self.table[obs, action_index]
        self.table[obs, action_index] = self.table[obs,action_index] + self.alpha*deltaQ

# %% [markdown]
# ### Agente

# %%
class Agent:
    def __init__(self, params: AgentParameters, actions_shape):
        self.epsilon_min = params.epsilon_min
        self.epsilon_decay = params.epsilon_decay
        self.epsilon = params.start_epsilon
        self.actions = [i for i in range(actions_shape)]


    def set_q_table(self, q_table: QTable):
        self.q_table = q_table


    def set_actions(self, actions):
        self.actions = actions


    def get_action(self, obs):
        if self.epsilon > self.epsilon_min:
            self.epsilon -= self.epsilon_decay
        if np.random.random() > self.epsilon:
            action_index = np.argmax(self.q_table.table[obs,:])
            self.action = self.actions[action_index]            
        else:
            action = np.random.choice(self.actions)
            self.action = action
        return self.action                
        

    def set_action(self, action_index: int):
        self.action_index = action_index
        self.action = self.actions[action_index]

# %% [markdown]
# ### Ambiente

# %% [markdown]
# Para a criação do ambiente, teve-se que pensar nos possíveis estados dele. Mesmo que o campo inteiro seja composto por 6 possíveis lugares para o rato estar, como existem campos com queijos e que não encerram o episódio, deve-se levar em conta que o rato na mesma posição pode significar mais de um estado, como na imagem a seguir.
#
# ![Rato](https://i.imgur.com/JDwfYqs.png)
# ![Rato](https://i.imgur.com/5OEUOfA.png)
#
# ![Rato](https://i.imgur.com/xsp4MY0.png)
# ![Rato](https://i.imgur.com/dLAKfuH.png)
#
#
# Portanto, para esse exemplo, existem 4 possíveis estados com o rato na mesma posição, sendo que seu estado depende diretamente da existência ou não de queijos em seus respectivos espaços. Levou-se em consideração todos os possíveis estados em cada posição do rato. O estado em si é ou obtido diretamente pela leitura da matriz ou pela execução do método indicado que tanto leva em consideração a existência ou não de queijos em posições específicas quanto um *range* que não permite a sobreposição de número de estados.
#
# A matriz de estados, métodos e controle dos estados foram feitos no bloco de código a seguir.

# %%
class RatEnv:
    def __init__(self):
        self.grid = [['R', 5, 0],[100, -1000, 1000]]
        self.row = 0
        self.column = 0
        self.states = [[self.get_0_0, self.get_0_1, self.get_0_2],[self.get_1_0, 12, 13]]
    
    def reset(self):
        self.grid = [['R', 5, 0],[100, -1000, 1000]]
        self.row = 0
        self.column = 0
        self.states = [[self.get_0_0, self.get_0_1, self.get_0_2],[self.get_1_0, 10, 11]]
        return 0

    # Métodos responsáveis por obter o valor do estado baseando-se na existência ou não de 
    # queijos nos lugares pré-determinados.

    # Método que indica o estado quando o rato esta na posição (0,0)
    def get_0_0(self):
        return bool(self.grid[0][1]) + bool(self.grid[1][0])

    # Método que indica o estado quando o rato esta na posição (0,1)
    def get_0_1(self):
        return bool(self.grid[1][0]) + 6

    # Método que indica o estado quando o rato esta na posição (0,2)
    def get_0_2(self):
        return bool(self.grid[1][0]) + 8

    # Método que indica o estado quando o rato esta na posição (1,0)
    def get_1_0(self):
        return bool(self.grid[0][1]) + 4

    # Método que aplica uma ação, atualiza o ambiente e retorna o estado
    def step(self, action):
        done = False
        reward = 0
        if (action == 'RIGHT' or action == 3):
            if (self.column + 1 >= len(self.grid[0])):
                reward = 0
            else:
                reward = self.grid[self.row][self.column + 1]
                self.grid[self.row][self.column] = 0
                self.grid[self.row][self.column + 1] = 'R'
                self.column += 1
                if (abs(reward) > 500):
                    done = True
        elif (action == 'LEFT' or action == 1):
            if (self.column - 1 < 0):
                reward = 0
            else:
                reward = self.grid[self.row][self.column - 1]
                self.grid[self.row][self.column] = 0
                self.grid[self.row][self.column - 1] = 'R'
                self.column -= 1
                if (abs(reward) > 500):
                    done = True

        elif (action == 'UP' or action == 2):
            if (self.row - 1 < 0):
                reward = 0
            else:
                reward = self.grid[self.row - 1][self.column]
                self.grid[self.row][self.column] = 0
                self.grid[self.row - 1][self.column] = 'R'
                self.row -= 1
                if (abs(reward) > 500):
                    done = True
        elif (action == 'DOWN' or action == 0):
            if (self.row + 1 >= len(self.grid)):
                reward = 0
            else:
                reward = self.grid[self.row + 1][self.column]
                self.grid[self.row][self.column] = 0
                self.grid[self.row + 1][self.column] = 'R'
                self.row += 1
                if (abs(reward) > 500):
                    done = True

        # Obtenção do estado a partir da matriz de estados.
        # Caso o estado seja um método, ele deve ser executado pois seu valor depende
        # da existência ou não de ao menos um queijo do ambiente
        state = self.states[self.row][self.column]
        if (not isinstance(state, int)):
            state = state()
        return state, reward - 1, done, "debug stuff here"

    def render(self):
        for r in self.grid:
            print(r)

# %%
# Parâmetros para o modelo

EPSILON_MIN = 0.05
MAX_NUM_EPISODES = 1000
STEPS_PER_EPISODE = 10
max_num_steps = MAX_NUM_EPISODES * STEPS_PER_EPISODE
ALPHA = 0.01
GAMMA = 0.999
EPSILON_DECAY = 25 * EPSILON_MIN / max_num_steps
np.random.seed(123)


# Objetos utilizados no sistema com os parâmetros especificados e calculados acima
learning_parameters = LearningParameters(ALPHA, GAMMA)
agent_parameters = AgentParameters(EPSILON_MIN, EPSILON_DECAY, 1)
training_parameters = TrainingParameters(MAX_NUM_EPISODES, STEPS_PER_EPISODE)

# Criação da tabela Q com 12 estados
rat_q_table = QTable(12, 4, learning_parameters)

# Criação do agente e indicação de sua tabela Q
rat_agent = Agent(agent_parameters, 4)
rat_agent.set_q_table(rat_q_table)

# Criação do ambiente
env = RatEnv()

# %% [markdown]
# ### Treino

# %%
# Função responsável por treinar o agente a partir dos rewards e com uma limitação
# número máximo de passos possíveis por episódio
def train(agent: Agent, env, params: TrainingParameters):
    best_reward = -float('inf')
    for episode in range(MAX_NUM_EPISODES):
        obs = env.reset()
        done = False
        total_reward = 0.0
        steps = 0
        while (not done and steps < params.steps_per_episode):
            steps += 1
            action = agent.get_action(obs)
            next_obs, reward, done, info = env.step(action)
            agent.q_table.learn(obs, action, reward, next_obs)
            obs = next_obs
            total_reward += reward
            # if total_reward < 0:
            #     break
        if total_reward > best_reward:
            best_reward = total_reward
        print("Episode#:{} reward:{} best_reward:{} eps:{}".format(episode,
            total_reward, best_reward, agent.epsilon))
    return np.argmax(agent.q_table.table, axis=1)

# %%
# Treino e obtenção da política de ação por estado
learned_policy = train(rat_agent, env, training_parameters)
# Out:
# Episode#:0 reward:95.0 best_reward:95.0 eps:0.9987499999999996
# Episode#:1 reward:95.0 best_reward:95.0 eps:0.9974999999999992
# Episode#:2 reward:-908.0 best_reward:95.0 eps:0.9964999999999988
# Episode#:3 reward:95.0 best_reward:95.0 eps:0.9952499999999984
# Episode#:4 reward:-902.0 best_reward:95.0 eps:0.9949999999999983
# Episode#:5 reward:-5.0 best_reward:95.0 eps:0.9937499999999979
# Episode#:6 reward:-5.0 best_reward:95.0 eps:0.9924999999999975
# Episode#:7 reward:-997.0 best_reward:95.0 eps:0.9922499999999974
# Episode#:8 reward:95.0 best_reward:95.0 eps:0.990999999999997
# Episode#:9 reward:-5.0 best_reward:95.0 eps:0.9897499999999966
# Episode#:10 reward:-902.0 best_reward:95.0 eps:0.9894999999999965
# Episode#:11 reward:-997.0 best_reward:95.0 eps:0.9892499999999964
# Episode#:12 reward:998.0 best_reward:998.0 eps:0.9883749999999961
# Episode#:13 reward:-1002.0 best_reward:998.0 eps:0.9874999999999958
# Episode#:14 reward:-904.0 best_reward:998.0 eps:0.9869999999999957
# Episode#:15 reward:95.0 best_reward:998.0 eps:0.9857499999999952
# Episode#:16 reward:-903.0 best_reward:998.0 eps:0.9853749999999951
# Episode#:17 reward:90.0 best_reward:998.0 eps:0.9841249999999947
# Episode#:18 reward:-999.0 best_reward:998.0 eps:0.9836249999999945
# Episode#:19 reward:-906.0 best_reward:998.0 eps:0.9828749999999943
# Episode#:20 reward:-997.0 best_reward:998.0 eps:0.9826249999999942
# Episode#:21 reward:1000.0 best_reward:1000.0 eps:0.981999999999994
# Episode#:22 reward:1000.0 best_reward:1000.0 eps:0.9813749999999938
# Episode#:23 reward:-908.0 best_reward:1000.0 eps:0.9803749999999934
# Episode#:24 reward:1001.0 best_reward:1001.0 eps:0.9798749999999933
# Episode#:25 reward:-902.0 best_reward:1001.0 eps:0.9796249999999932
# Episode#:26 reward:95.0 best_reward:1001.0 eps:0.9783749999999928
# Episode#:27 reward:-5.0 best_reward:1001.0 eps:0.9771249999999924
# Episode#:28 reward:-997.0 best_reward:1001.0 eps:0.9768749999999923
# Episode#:29 reward:-999.0 best_reward:1001.0 eps:0.9763749999999921
# Episode#:30 reward:-901.0 best_reward:1001.0 eps:0.9756249999999919
# Episode#:31 reward:-901.0 best_reward:1001.0 eps:0.9748749999999916
# Episode#:32 reward:-1002.0 best_reward:1001.0 eps:0.9739999999999913
# Episode#:33 reward:90.0 best_reward:1001.0 eps:0.9727499999999909
# Episode#:34 reward:-908.0 best_reward:1001.0 eps:0.9717499999999906
# Episode#:35 reward:-904.0 best_reward:1001.0 eps:0.9712499999999904
# Episode#:36 reward:-909.0 best_reward:1001.0 eps:0.97012499999999
# Episode#:37 reward:-5.0 best_reward:1001.0 eps:0.9688749999999896
# Episode#:38 reward:-999.0 best_reward:1001.0 eps:0.9683749999999894
# Episode#:39 reward:-1001.0 best_reward:1001.0 eps:0.9676249999999892
# Episode#:40 reward:-902.0 best_reward:1001.0 eps:0.9673749999999891
# Episode#:41 reward:-1001.0 best_reward:1001.0 eps:0.9666249999999889
# Episode#:42 reward:-1002.0 best_reward:1001.0 eps:0.9657499999999886
# Episode#:43 reward:998.0 best_reward:1001.0 eps:0.9648749999999883
# Episode#:44 reward:998.0 best_reward:1001.0 eps:0.963999999999988
# Episode#:45 reward:-904.0 best_reward:1001.0 eps:0.9634999999999878
# Episode#:46 reward:95.0 best_reward:1001.0 eps:0.9622499999999874
# Episode#:47 reward:-1002.0 best_reward:1001.0 eps:0.9613749999999871
# Episode#:48 reward:-997.0 best_reward:1001.0 eps:0.961124999999987
# Episode#:49 reward:-901.0 best_reward:1001.0 eps:0.9603749999999868
# Episode#:50 reward:-1002.0 best_reward:1001.0 eps:0.9594999999999865
# Episode#:51 reward:-905.0 best_reward:1001.0 eps:0.9582499999999861
# Episode#:52 reward:-900.0 best_reward:1001.0 eps:0.9576249999999858
# Episode#:53 reward:-904.0 best_reward:1001.0 eps:0.9564999999999855
# Episode#:54 reward:-997.0 best_reward:1001.0 eps:0.9562499999999854
# Episode#:55 reward:-904.0 best_reward:1001.0 eps:0.9557499999999852
# Episode#:56 reward:997.0 best_reward:1001.0 eps:0.9547499999999849
# Episode#:57 reward:-909.0 best_reward:1001.0 eps:0.9536249999999845
# Episode#:58 reward:1097.0 best_reward:1097.0 eps:0.9526249999999842
# Episode#:59 reward:95.0 best_reward:1097.0 eps:0.9513749999999838
# Episode#:60 reward:90.0 best_reward:1097.0 eps:0.9501249999999833
# Episode#:61 reward:-901.0 best_reward:1097.0 eps:0.9493749999999831
# Episode#:62 reward:1099.0 best_reward:1099.0 eps:0.9486249999999828
# Episode#:63 reward:95.0 best_reward:1099.0 eps:0.9473749999999824
# Episode#:64 reward:-999.0 best_reward:1099.0 eps:0.9468749999999823
# Episode#:65 reward:-907.0 best_reward:1099.0 eps:0.945999999999982
# Episode#:66 reward:-998.0 best_reward:1099.0 eps:0.9456249999999818
# Episode#:67 reward:-904.0 best_reward:1099.0 eps:0.9451249999999817
# Episode#:68 reward:-904.0 best_reward:1099.0 eps:0.9446249999999815
# Episode#:69 reward:1000.0 best_reward:1099.0 eps:0.9439999999999813
# Episode#:70 reward:-903.0 best_reward:1099.0 eps:0.9436249999999812
# Episode#:71 reward:90.0 best_reward:1099.0 eps:0.9423749999999808
# Episode#:72 reward:-901.0 best_reward:1099.0 eps:0.9416249999999805
# Episode#:73 reward:-905.0 best_reward:1099.0 eps:0.9409999999999803
# Episode#:74 reward:-904.0 best_reward:1099.0 eps:0.9404999999999801
# Episode#:75 reward:-907.0 best_reward:1099.0 eps:0.9396249999999798
# Episode#:76 reward:-997.0 best_reward:1099.0 eps:0.9393749999999798
# Episode#:77 reward:-903.0 best_reward:1099.0 eps:0.9383749999999794
# Episode#:78 reward:95.0 best_reward:1099.0 eps:0.937124999999979
# Episode#:79 reward:95.0 best_reward:1099.0 eps:0.9358749999999786
# Episode#:80 reward:-902.0 best_reward:1099.0 eps:0.9349999999999783
# Episode#:81 reward:-998.0 best_reward:1099.0 eps:0.9346249999999782
# Episode#:82 reward:-904.0 best_reward:1099.0 eps:0.934124999999978
# Episode#:83 reward:-906.0 best_reward:1099.0 eps:0.9333749999999778
# Episode#:84 reward:1000.0 best_reward:1099.0 eps:0.9327499999999775
# Episode#:85 reward:-905.0 best_reward:1099.0 eps:0.9321249999999773
# Episode#:86 reward:95.0 best_reward:1099.0 eps:0.9308749999999769
# Episode#:87 reward:-999.0 best_reward:1099.0 eps:0.9303749999999767
# Episode#:88 reward:-997.0 best_reward:1099.0 eps:0.9301249999999767
# Episode#:89 reward:-906.0 best_reward:1099.0 eps:0.9293749999999764
# Episode#:90 reward:-999.0 best_reward:1099.0 eps:0.9288749999999762
# Episode#:91 reward:-904.0 best_reward:1099.0 eps:0.9277499999999759
# Episode#:92 reward:-906.0 best_reward:1099.0 eps:0.9269999999999756
# Episode#:93 reward:-900.0 best_reward:1099.0 eps:0.9263749999999754
# Episode#:94 reward:-5.0 best_reward:1099.0 eps:0.925124999999975
# Episode#:95 reward:-906.0 best_reward:1099.0 eps:0.9243749999999747
# Episode#:96 reward:-906.0 best_reward:1099.0 eps:0.9236249999999745
# Episode#:97 reward:-903.0 best_reward:1099.0 eps:0.9232499999999744
# Episode#:98 reward:-906.0 best_reward:1099.0 eps:0.9224999999999741
# Episode#:99 reward:-997.0 best_reward:1099.0 eps:0.922249999999974
# Episode#:100 reward:997.0 best_reward:1099.0 eps:0.9212499999999737
# Episode#:101 reward:-1000.0 best_reward:1099.0 eps:0.9206249999999735
# Episode#:102 reward:1002.0 best_reward:1099.0 eps:0.9202499999999734
# Episode#:103 reward:-903.0 best_reward:1099.0 eps:0.919249999999973
# Episode#:104 reward:-5.0 best_reward:1099.0 eps:0.9179999999999726
# Episode#:105 reward:-999.0 best_reward:1099.0 eps:0.9174999999999724
# Episode#:106 reward:1001.0 best_reward:1099.0 eps:0.9169999999999723
# Episode#:107 reward:-905.0 best_reward:1099.0 eps:0.9163749999999721
# Episode#:108 reward:-5.0 best_reward:1099.0 eps:0.9151249999999717
# Episode#:109 reward:-5.0 best_reward:1099.0 eps:0.9138749999999712
# Episode#:110 reward:90.0 best_reward:1099.0 eps:0.9126249999999708
# Episode#:111 reward:-902.0 best_reward:1099.0 eps:0.9123749999999707
# Episode#:112 reward:-908.0 best_reward:1099.0 eps:0.9113749999999704
# Episode#:113 reward:90.0 best_reward:1099.0 eps:0.91012499999997
# Episode#:114 reward:90.0 best_reward:1099.0 eps:0.9088749999999696
# Episode#:115 reward:-903.0 best_reward:1099.0 eps:0.9084999999999694
# Episode#:116 reward:-909.0 best_reward:1099.0 eps:0.9073749999999691
# Episode#:117 reward:90.0 best_reward:1099.0 eps:0.9061249999999686
# Episode#:118 reward:997.0 best_reward:1099.0 eps:0.9051249999999683
# Episode#:119 reward:-906.0 best_reward:1099.0 eps:0.9043749999999681
# Episode#:120 reward:-902.0 best_reward:1099.0 eps:0.904124999999968
# Episode#:121 reward:-998.0 best_reward:1099.0 eps:0.9037499999999679
# Episode#:122 reward:-999.0 best_reward:1099.0 eps:0.9032499999999677
# Episode#:123 reward:95.0 best_reward:1099.0 eps:0.9019999999999673
# Episode#:124 reward:95.0 best_reward:1099.0 eps:0.9007499999999669
# Episode#:125 reward:95.0 best_reward:1099.0 eps:0.8994999999999664
# Episode#:126 reward:-999.0 best_reward:1099.0 eps:0.8989999999999663
# Episode#:127 reward:90.0 best_reward:1099.0 eps:0.8977499999999659
# Episode#:128 reward:1096.0 best_reward:1099.0 eps:0.8966249999999655
# Episode#:129 reward:-900.0 best_reward:1099.0 eps:0.8959999999999653
# Episode#:130 reward:1000.0 best_reward:1099.0 eps:0.8953749999999651
# Episode#:131 reward:-909.0 best_reward:1099.0 eps:0.8942499999999647
# Episode#:132 reward:-902.0 best_reward:1099.0 eps:0.8933749999999644
# Episode#:133 reward:1001.0 best_reward:1099.0 eps:0.8928749999999642
# Episode#:134 reward:-1000.0 best_reward:1099.0 eps:0.892249999999964
# Episode#:135 reward:-902.0 best_reward:1099.0 eps:0.8919999999999639
# Episode#:136 reward:-900.0 best_reward:1099.0 eps:0.8913749999999637
# Episode#:137 reward:1095.0 best_reward:1099.0 eps:0.8901249999999633
# Episode#:138 reward:-903.0 best_reward:1099.0 eps:0.8897499999999632
# Episode#:139 reward:1002.0 best_reward:1099.0 eps:0.8893749999999631
# Episode#:140 reward:95.0 best_reward:1099.0 eps:0.8881249999999626
# Episode#:141 reward:95.0 best_reward:1099.0 eps:0.8868749999999622
# Episode#:142 reward:997.0 best_reward:1099.0 eps:0.8858749999999619
# Episode#:143 reward:-904.0 best_reward:1099.0 eps:0.8853749999999617
# Episode#:144 reward:-997.0 best_reward:1099.0 eps:0.8851249999999616
# Episode#:145 reward:95.0 best_reward:1099.0 eps:0.8838749999999612
# Episode#:146 reward:95.0 best_reward:1099.0 eps:0.8826249999999608
# Episode#:147 reward:-903.0 best_reward:1099.0 eps:0.8822499999999607
# Episode#:148 reward:-907.0 best_reward:1099.0 eps:0.8813749999999604
# Episode#:149 reward:-905.0 best_reward:1099.0 eps:0.8807499999999602
# Episode#:150 reward:-998.0 best_reward:1099.0 eps:0.88037499999996
# Episode#:151 reward:-1000.0 best_reward:1099.0 eps:0.8797499999999598
# Episode#:152 reward:-999.0 best_reward:1099.0 eps:0.8792499999999597
# Episode#:153 reward:-905.0 best_reward:1099.0 eps:0.8779999999999593
# Episode#:154 reward:-904.0 best_reward:1099.0 eps:0.8774999999999591
# Episode#:155 reward:-902.0 best_reward:1099.0 eps:0.877249999999959
# Episode#:156 reward:-902.0 best_reward:1099.0 eps:0.8769999999999589
# Episode#:157 reward:95.0 best_reward:1099.0 eps:0.8757499999999585
# Episode#:158 reward:1001.0 best_reward:1099.0 eps:0.8752499999999583
# Episode#:159 reward:-901.0 best_reward:1099.0 eps:0.8744999999999581
# Episode#:160 reward:-906.0 best_reward:1099.0 eps:0.8737499999999578
# Episode#:161 reward:95.0 best_reward:1099.0 eps:0.8724999999999574
# Episode#:162 reward:95.0 best_reward:1099.0 eps:0.871249999999957
# Episode#:163 reward:90.0 best_reward:1099.0 eps:0.8699999999999566
# Episode#:164 reward:-998.0 best_reward:1099.0 eps:0.8696249999999565
# Episode#:165 reward:-997.0 best_reward:1099.0 eps:0.8693749999999564
# Episode#:166 reward:90.0 best_reward:1099.0 eps:0.868124999999956
# Episode#:167 reward:95.0 best_reward:1099.0 eps:0.8668749999999555
# Episode#:168 reward:-904.0 best_reward:1099.0 eps:0.8663749999999554
# Episode#:169 reward:-1001.0 best_reward:1099.0 eps:0.8656249999999551
# Episode#:170 reward:-5.0 best_reward:1099.0 eps:0.8643749999999547
# Episode#:171 reward:-10.0 best_reward:1099.0 eps:0.8631249999999543
# Episode#:172 reward:1002.0 best_reward:1099.0 eps:0.8627499999999542
# Episode#:173 reward:995.0 best_reward:1099.0 eps:0.8614999999999537
# Episode#:174 reward:1001.0 best_reward:1099.0 eps:0.8609999999999536
# Episode#:175 reward:-903.0 best_reward:1099.0 eps:0.8606249999999535
# Episode#:176 reward:-903.0 best_reward:1099.0 eps:0.8596249999999531
# Episode#:177 reward:1002.0 best_reward:1099.0 eps:0.859249999999953
# Episode#:178 reward:1098.0 best_reward:1099.0 eps:0.8583749999999527
# Episode#:179 reward:-903.0 best_reward:1099.0 eps:0.8579999999999526
# Episode#:180 reward:-906.0 best_reward:1099.0 eps:0.8572499999999523
# Episode#:181 reward:1095.0 best_reward:1099.0 eps:0.8559999999999519
# Episode#:182 reward:999.0 best_reward:1099.0 eps:0.8552499999999517
# Episode#:183 reward:90.0 best_reward:1099.0 eps:0.8539999999999512
# Episode#:184 reward:-902.0 best_reward:1099.0 eps:0.8537499999999512
# Episode#:185 reward:-905.0 best_reward:1099.0 eps:0.853124999999951
# Episode#:186 reward:1000.0 best_reward:1099.0 eps:0.8524999999999507
# Episode#:187 reward:-997.0 best_reward:1099.0 eps:0.8522499999999507
# Episode#:188 reward:-901.0 best_reward:1099.0 eps:0.8514999999999504
# Episode#:189 reward:-902.0 best_reward:1099.0 eps:0.8512499999999503
# Episode#:190 reward:95.0 best_reward:1099.0 eps:0.8499999999999499
# Episode#:191 reward:90.0 best_reward:1099.0 eps:0.8487499999999495
# Episode#:192 reward:90.0 best_reward:1099.0 eps:0.8474999999999491
# Episode#:193 reward:-903.0 best_reward:1099.0 eps:0.847124999999949
# Episode#:194 reward:-909.0 best_reward:1099.0 eps:0.8459999999999486
# Episode#:195 reward:-905.0 best_reward:1099.0 eps:0.8453749999999484
# Episode#:196 reward:1095.0 best_reward:1099.0 eps:0.844124999999948
# Episode#:197 reward:998.0 best_reward:1099.0 eps:0.8432499999999477
# Episode#:198 reward:-905.0 best_reward:1099.0 eps:0.8419999999999472
# Episode#:199 reward:-5.0 best_reward:1099.0 eps:0.8407499999999468
# Episode#:200 reward:-902.0 best_reward:1099.0 eps:0.8398749999999465
# Episode#:201 reward:-904.0 best_reward:1099.0 eps:0.8393749999999464
# Episode#:202 reward:-904.0 best_reward:1099.0 eps:0.8388749999999462
# Episode#:203 reward:95.0 best_reward:1099.0 eps:0.8376249999999458
# Episode#:204 reward:-903.0 best_reward:1099.0 eps:0.8372499999999456
# Episode#:205 reward:-1001.0 best_reward:1099.0 eps:0.8364999999999454
# Episode#:206 reward:1000.0 best_reward:1099.0 eps:0.8358749999999452
# Episode#:207 reward:-904.0 best_reward:1099.0 eps:0.835374999999945
# Episode#:208 reward:-905.0 best_reward:1099.0 eps:0.8347499999999448
# Episode#:209 reward:95.0 best_reward:1099.0 eps:0.8334999999999444
# Episode#:210 reward:-1001.0 best_reward:1099.0 eps:0.8327499999999441
# Episode#:211 reward:95.0 best_reward:1099.0 eps:0.8314999999999437
# Episode#:212 reward:95.0 best_reward:1099.0 eps:0.8302499999999433
# Episode#:213 reward:95.0 best_reward:1099.0 eps:0.8289999999999429
# Episode#:214 reward:-907.0 best_reward:1099.0 eps:0.8281249999999426
# Episode#:215 reward:-903.0 best_reward:1099.0 eps:0.8271249999999423
# Episode#:216 reward:-902.0 best_reward:1099.0 eps:0.8268749999999422
# Episode#:217 reward:-1001.0 best_reward:1099.0 eps:0.8261249999999419
# Episode#:218 reward:1002.0 best_reward:1099.0 eps:0.8257499999999418
# Episode#:219 reward:-997.0 best_reward:1099.0 eps:0.8254999999999417
# Episode#:220 reward:-902.0 best_reward:1099.0 eps:0.8252499999999416
# Episode#:221 reward:1001.0 best_reward:1099.0 eps:0.8247499999999415
# Episode#:222 reward:-899.0 best_reward:1099.0 eps:0.8242499999999413
# Episode#:223 reward:-997.0 best_reward:1099.0 eps:0.8239999999999412
# Episode#:224 reward:-905.0 best_reward:1099.0 eps:0.823374999999941
# Episode#:225 reward:-902.0 best_reward:1099.0 eps:0.8224999999999407
# Episode#:226 reward:90.0 best_reward:1099.0 eps:0.8212499999999403
# Episode#:227 reward:-902.0 best_reward:1099.0 eps:0.8209999999999402
# Episode#:228 reward:-905.0 best_reward:1099.0 eps:0.82037499999994
# Episode#:229 reward:-909.0 best_reward:1099.0 eps:0.8192499999999396
# Episode#:230 reward:998.0 best_reward:1099.0 eps:0.8183749999999393
# Episode#:231 reward:-997.0 best_reward:1099.0 eps:0.8181249999999393
# Episode#:232 reward:95.0 best_reward:1099.0 eps:0.8168749999999388
# Episode#:233 reward:-999.0 best_reward:1099.0 eps:0.8163749999999387
# Episode#:234 reward:90.0 best_reward:1099.0 eps:0.8151249999999383
# Episode#:235 reward:1002.0 best_reward:1099.0 eps:0.8147499999999381
# Episode#:236 reward:95.0 best_reward:1099.0 eps:0.8134999999999377
# Episode#:237 reward:-904.0 best_reward:1099.0 eps:0.8123749999999373
# Episode#:238 reward:-905.0 best_reward:1099.0 eps:0.8117499999999371
# Episode#:239 reward:-998.0 best_reward:1099.0 eps:0.811374999999937
# Episode#:240 reward:-905.0 best_reward:1099.0 eps:0.8101249999999366
# Episode#:241 reward:90.0 best_reward:1099.0 eps:0.8088749999999362
# Episode#:242 reward:996.0 best_reward:1099.0 eps:0.8077499999999358
# Episode#:243 reward:90.0 best_reward:1099.0 eps:0.8064999999999354
# Episode#:244 reward:-997.0 best_reward:1099.0 eps:0.8062499999999353
# Episode#:245 reward:-902.0 best_reward:1099.0 eps:0.8059999999999352
# Episode#:246 reward:1001.0 best_reward:1099.0 eps:0.805499999999935
# Episode#:247 reward:-905.0 best_reward:1099.0 eps:0.8048749999999348
# Episode#:248 reward:-905.0 best_reward:1099.0 eps:0.8042499999999346
# Episode#:249 reward:90.0 best_reward:1099.0 eps:0.8029999999999342
# Episode#:250 reward:1001.0 best_reward:1099.0 eps:0.802499999999934
# Episode#:251 reward:1002.0 best_reward:1099.0 eps:0.8021249999999339
# Episode#:252 reward:95.0 best_reward:1099.0 eps:0.8008749999999335
# Episode#:253 reward:90.0 best_reward:1099.0 eps:0.7996249999999331
# Episode#:254 reward:999.0 best_reward:1099.0 eps:0.7988749999999328
# Episode#:255 reward:1001.0 best_reward:1099.0 eps:0.7983749999999327
# Episode#:256 reward:1002.0 best_reward:1099.0 eps:0.7979999999999325
# Episode#:257 reward:-902.0 best_reward:1099.0 eps:0.7971249999999322
# Episode#:258 reward:90.0 best_reward:1099.0 eps:0.7958749999999318
# Episode#:259 reward:999.0 best_reward:1099.0 eps:0.7951249999999316
# Episode#:260 reward:-902.0 best_reward:1099.0 eps:0.7948749999999315
# Episode#:261 reward:1000.0 best_reward:1099.0 eps:0.7942499999999313
# Episode#:262 reward:-902.0 best_reward:1099.0 eps:0.793374999999931
# Episode#:263 reward:1095.0 best_reward:1099.0 eps:0.7921249999999306
# Episode#:264 reward:1002.0 best_reward:1099.0 eps:0.7917499999999305
# Episode#:265 reward:-904.0 best_reward:1099.0 eps:0.7912499999999303
# Episode#:266 reward:998.0 best_reward:1099.0 eps:0.79037499999993
# Episode#:267 reward:-903.0 best_reward:1099.0 eps:0.7899999999999299
# Episode#:268 reward:-905.0 best_reward:1099.0 eps:0.7893749999999297
# Episode#:269 reward:-904.0 best_reward:1099.0 eps:0.7888749999999295
# Episode#:270 reward:-900.0 best_reward:1099.0 eps:0.7882499999999293
# Episode#:271 reward:95.0 best_reward:1099.0 eps:0.7869999999999289
# Episode#:272 reward:-902.0 best_reward:1099.0 eps:0.7867499999999288
# Episode#:273 reward:-903.0 best_reward:1099.0 eps:0.7857499999999285
# Episode#:274 reward:-903.0 best_reward:1099.0 eps:0.7853749999999283
# Episode#:275 reward:1098.0 best_reward:1099.0 eps:0.784499999999928
# Episode#:276 reward:997.0 best_reward:1099.0 eps:0.7834999999999277
# Episode#:277 reward:95.0 best_reward:1099.0 eps:0.7822499999999273
# Episode#:278 reward:95.0 best_reward:1099.0 eps:0.7809999999999269
# Episode#:279 reward:95.0 best_reward:1099.0 eps:0.7797499999999264
# Episode#:280 reward:-903.0 best_reward:1099.0 eps:0.7793749999999263
# Episode#:281 reward:-903.0 best_reward:1099.0 eps:0.7789999999999262
# Episode#:282 reward:90.0 best_reward:1099.0 eps:0.7777499999999258
# Episode#:283 reward:-5.0 best_reward:1099.0 eps:0.7764999999999254
# Episode#:284 reward:1099.0 best_reward:1099.0 eps:0.7757499999999251
# Episode#:285 reward:1000.0 best_reward:1099.0 eps:0.7751249999999249
# Episode#:286 reward:-997.0 best_reward:1099.0 eps:0.7748749999999248
# Episode#:287 reward:95.0 best_reward:1099.0 eps:0.7736249999999244
# Episode#:288 reward:1000.0 best_reward:1099.0 eps:0.7729999999999242
# Episode#:289 reward:-997.0 best_reward:1099.0 eps:0.7727499999999241
# Episode#:290 reward:90.0 best_reward:1099.0 eps:0.7714999999999237
# Episode#:291 reward:1002.0 best_reward:1099.0 eps:0.7711249999999236
# Episode#:292 reward:95.0 best_reward:1099.0 eps:0.7698749999999231
# Episode#:293 reward:1002.0 best_reward:1099.0 eps:0.769499999999923
# Episode#:294 reward:-908.0 best_reward:1099.0 eps:0.7684999999999227
# Episode#:295 reward:90.0 best_reward:1099.0 eps:0.7672499999999223
# Episode#:296 reward:-903.0 best_reward:1099.0 eps:0.7668749999999221
# Episode#:297 reward:90.0 best_reward:1099.0 eps:0.7656249999999217
# Episode#:298 reward:-906.0 best_reward:1099.0 eps:0.7648749999999215
# Episode#:299 reward:90.0 best_reward:1099.0 eps:0.7636249999999211
# Episode#:300 reward:-999.0 best_reward:1099.0 eps:0.7631249999999209
# Episode#:301 reward:-997.0 best_reward:1099.0 eps:0.7628749999999208
# Episode#:302 reward:-906.0 best_reward:1099.0 eps:0.7621249999999206
# Episode#:303 reward:-1001.0 best_reward:1099.0 eps:0.7613749999999203
# Episode#:304 reward:95.0 best_reward:1099.0 eps:0.7601249999999199
# Episode#:305 reward:-905.0 best_reward:1099.0 eps:0.7588749999999195
# Episode#:306 reward:-904.0 best_reward:1099.0 eps:0.7583749999999193
# Episode#:307 reward:-902.0 best_reward:1099.0 eps:0.757499999999919
# Episode#:308 reward:90.0 best_reward:1099.0 eps:0.7562499999999186
# Episode#:309 reward:95.0 best_reward:1099.0 eps:0.7549999999999182
# Episode#:310 reward:-906.0 best_reward:1099.0 eps:0.7542499999999179
# Episode#:311 reward:-908.0 best_reward:1099.0 eps:0.7532499999999176
# Episode#:312 reward:1000.0 best_reward:1099.0 eps:0.7526249999999174
# Episode#:313 reward:-899.0 best_reward:1099.0 eps:0.7521249999999172
# Episode#:314 reward:-903.0 best_reward:1099.0 eps:0.7517499999999171
# Episode#:315 reward:-998.0 best_reward:1099.0 eps:0.751374999999917
# Episode#:316 reward:90.0 best_reward:1099.0 eps:0.7501249999999166
# Episode#:317 reward:95.0 best_reward:1099.0 eps:0.7488749999999161
# Episode#:318 reward:95.0 best_reward:1099.0 eps:0.7476249999999157
# Episode#:319 reward:-997.0 best_reward:1099.0 eps:0.7473749999999156
# Episode#:320 reward:-904.0 best_reward:1099.0 eps:0.7468749999999155
# Episode#:321 reward:-899.0 best_reward:1099.0 eps:0.7463749999999153
# Episode#:322 reward:90.0 best_reward:1099.0 eps:0.7451249999999149
# Episode#:323 reward:999.0 best_reward:1099.0 eps:0.7443749999999146
# Episode#:324 reward:95.0 best_reward:1099.0 eps:0.7431249999999142
# Episode#:325 reward:95.0 best_reward:1099.0 eps:0.7418749999999138
# Episode#:326 reward:95.0 best_reward:1099.0 eps:0.7406249999999134
# Episode#:327 reward:-902.0 best_reward:1099.0 eps:0.7403749999999133
# Episode#:328 reward:1002.0 best_reward:1099.0 eps:0.7399999999999132
# Episode#:329 reward:-903.0 best_reward:1099.0 eps:0.739624999999913
# Episode#:330 reward:90.0 best_reward:1099.0 eps:0.7383749999999126
# Episode#:331 reward:-997.0 best_reward:1099.0 eps:0.7381249999999125
# Episode#:332 reward:95.0 best_reward:1099.0 eps:0.7368749999999121
# Episode#:333 reward:-908.0 best_reward:1099.0 eps:0.7358749999999118
# Episode#:334 reward:1099.0 best_reward:1099.0 eps:0.7351249999999115
# Episode#:335 reward:1095.0 best_reward:1099.0 eps:0.7338749999999111
# Episode#:336 reward:95.0 best_reward:1099.0 eps:0.7326249999999107
# Episode#:337 reward:95.0 best_reward:1099.0 eps:0.7313749999999103
# Episode#:338 reward:90.0 best_reward:1099.0 eps:0.7301249999999099
# Episode#:339 reward:1097.0 best_reward:1099.0 eps:0.7291249999999095
# Episode#:340 reward:90.0 best_reward:1099.0 eps:0.7278749999999091
# Episode#:341 reward:-902.0 best_reward:1099.0 eps:0.727624999999909
# Episode#:342 reward:90.0 best_reward:1099.0 eps:0.7263749999999086
# Episode#:343 reward:1099.0 best_reward:1099.0 eps:0.7256249999999084
# Episode#:344 reward:90.0 best_reward:1099.0 eps:0.724374999999908
# Episode#:345 reward:-904.0 best_reward:1099.0 eps:0.7238749999999078
# Episode#:346 reward:-905.0 best_reward:1099.0 eps:0.7232499999999076
# Episode#:347 reward:-904.0 best_reward:1099.0 eps:0.7227499999999074
# Episode#:348 reward:-903.0 best_reward:1099.0 eps:0.7223749999999073
# Episode#:349 reward:90.0 best_reward:1099.0 eps:0.7211249999999069
# Episode#:350 reward:90.0 best_reward:1099.0 eps:0.7198749999999065
# Episode#:351 reward:95.0 best_reward:1099.0 eps:0.718624999999906
# Episode#:352 reward:-902.0 best_reward:1099.0 eps:0.718374999999906
# Episode#:353 reward:998.0 best_reward:1099.0 eps:0.7174999999999057
# Episode#:354 reward:-903.0 best_reward:1099.0 eps:0.7171249999999055
# Episode#:355 reward:95.0 best_reward:1099.0 eps:0.7158749999999051
# Episode#:356 reward:-905.0 best_reward:1099.0 eps:0.7152499999999049
# Episode#:357 reward:-902.0 best_reward:1099.0 eps:0.7149999999999048
# Episode#:358 reward:1098.0 best_reward:1099.0 eps:0.7141249999999045
# Episode#:359 reward:1096.0 best_reward:1099.0 eps:0.7129999999999042
# Episode#:360 reward:1096.0 best_reward:1099.0 eps:0.7118749999999038
# Episode#:361 reward:-902.0 best_reward:1099.0 eps:0.7109999999999035
# Episode#:362 reward:1001.0 best_reward:1099.0 eps:0.7104999999999033
# Episode#:363 reward:95.0 best_reward:1099.0 eps:0.7092499999999029
# Episode#:364 reward:-908.0 best_reward:1099.0 eps:0.7082499999999026
# Episode#:365 reward:-905.0 best_reward:1099.0 eps:0.7076249999999024
# Episode#:366 reward:-904.0 best_reward:1099.0 eps:0.706499999999902
# Episode#:367 reward:-900.0 best_reward:1099.0 eps:0.7058749999999018
# Episode#:368 reward:90.0 best_reward:1099.0 eps:0.7046249999999014
# Episode#:369 reward:90.0 best_reward:1099.0 eps:0.7033749999999009
# Episode#:370 reward:1002.0 best_reward:1099.0 eps:0.7029999999999008
# Episode#:371 reward:95.0 best_reward:1099.0 eps:0.7017499999999004
# Episode#:372 reward:-903.0 best_reward:1099.0 eps:0.7013749999999003
# Episode#:373 reward:95.0 best_reward:1099.0 eps:0.7001249999998999
# Episode#:374 reward:95.0 best_reward:1099.0 eps:0.6988749999998994
# Episode#:375 reward:95.0 best_reward:1099.0 eps:0.697624999999899
# Episode#:376 reward:-998.0 best_reward:1099.0 eps:0.6972499999998989
# Episode#:377 reward:95.0 best_reward:1099.0 eps:0.6959999999998985
# Episode#:378 reward:997.0 best_reward:1099.0 eps:0.6949999999998981
# Episode#:379 reward:95.0 best_reward:1099.0 eps:0.6937499999998977
# Episode#:380 reward:90.0 best_reward:1099.0 eps:0.6924999999998973
# Episode#:381 reward:-910.0 best_reward:1099.0 eps:0.6912499999998969
# Episode#:382 reward:90.0 best_reward:1099.0 eps:0.6899999999998965
# Episode#:383 reward:-904.0 best_reward:1099.0 eps:0.6894999999998963
# Episode#:384 reward:-908.0 best_reward:1099.0 eps:0.688499999999896
# Episode#:385 reward:997.0 best_reward:1099.0 eps:0.6874999999998956
# Episode#:386 reward:-905.0 best_reward:1099.0 eps:0.6862499999998952
# Episode#:387 reward:-902.0 best_reward:1099.0 eps:0.6859999999998951
# Episode#:388 reward:-908.0 best_reward:1099.0 eps:0.6849999999998948
# Episode#:389 reward:95.0 best_reward:1099.0 eps:0.6837499999998944
# Episode#:390 reward:-899.0 best_reward:1099.0 eps:0.6832499999998942
# Episode#:391 reward:-906.0 best_reward:1099.0 eps:0.682499999999894
# Episode#:392 reward:999.0 best_reward:1099.0 eps:0.6817499999998937
# Episode#:393 reward:-906.0 best_reward:1099.0 eps:0.6809999999998935
# Episode#:394 reward:-997.0 best_reward:1099.0 eps:0.6807499999998934
# Episode#:395 reward:1099.0 best_reward:1099.0 eps:0.6799999999998931
# Episode#:396 reward:1096.0 best_reward:1099.0 eps:0.6788749999998928
# Episode#:397 reward:1002.0 best_reward:1099.0 eps:0.6784999999998926
# Episode#:398 reward:95.0 best_reward:1099.0 eps:0.6772499999998922
# Episode#:399 reward:-903.0 best_reward:1099.0 eps:0.6768749999998921
# Episode#:400 reward:90.0 best_reward:1099.0 eps:0.6756249999998917
# Episode#:401 reward:1099.0 best_reward:1099.0 eps:0.6748749999998914
# Episode#:402 reward:1002.0 best_reward:1099.0 eps:0.6744999999998913
# Episode#:403 reward:90.0 best_reward:1099.0 eps:0.6732499999998909
# Episode#:404 reward:-900.0 best_reward:1099.0 eps:0.6726249999998907
# Episode#:405 reward:-902.0 best_reward:1099.0 eps:0.6723749999998906
# Episode#:406 reward:90.0 best_reward:1099.0 eps:0.6711249999998902
# Episode#:407 reward:90.0 best_reward:1099.0 eps:0.6698749999998898
# Episode#:408 reward:-901.0 best_reward:1099.0 eps:0.6691249999998895
# Episode#:409 reward:-902.0 best_reward:1099.0 eps:0.6688749999998894
# Episode#:410 reward:90.0 best_reward:1099.0 eps:0.667624999999889
# Episode#:411 reward:90.0 best_reward:1099.0 eps:0.6663749999998886
# Episode#:412 reward:-5.0 best_reward:1099.0 eps:0.6651249999998882
# Episode#:413 reward:1001.0 best_reward:1099.0 eps:0.664624999999888
# Episode#:414 reward:90.0 best_reward:1099.0 eps:0.6633749999998876
# Episode#:415 reward:1002.0 best_reward:1099.0 eps:0.6629999999998875
# Episode#:416 reward:1095.0 best_reward:1099.0 eps:0.661749999999887
# Episode#:417 reward:-906.0 best_reward:1099.0 eps:0.6609999999998868
# Episode#:418 reward:1001.0 best_reward:1099.0 eps:0.6604999999998866
# Episode#:419 reward:-907.0 best_reward:1099.0 eps:0.6596249999998863
# Episode#:420 reward:-902.0 best_reward:1099.0 eps:0.6593749999998862
# Episode#:421 reward:-997.0 best_reward:1099.0 eps:0.6591249999998862
# Episode#:422 reward:-908.0 best_reward:1099.0 eps:0.6581249999998858
# Episode#:423 reward:90.0 best_reward:1099.0 eps:0.6568749999998854
# Episode#:424 reward:-997.0 best_reward:1099.0 eps:0.6566249999998853
# Episode#:425 reward:-999.0 best_reward:1099.0 eps:0.6561249999998852
# Episode#:426 reward:-905.0 best_reward:1099.0 eps:0.655499999999885
# Episode#:427 reward:-904.0 best_reward:1099.0 eps:0.6549999999998848
# Episode#:428 reward:1000.0 best_reward:1099.0 eps:0.6543749999998846
# Episode#:429 reward:90.0 best_reward:1099.0 eps:0.6531249999998842
# Episode#:430 reward:-906.0 best_reward:1099.0 eps:0.6523749999998839
# Episode#:431 reward:-904.0 best_reward:1099.0 eps:0.6518749999998837
# Episode#:432 reward:-909.0 best_reward:1099.0 eps:0.6507499999998834
# Episode#:433 reward:1000.0 best_reward:1099.0 eps:0.6501249999998832
# Episode#:434 reward:90.0 best_reward:1099.0 eps:0.6488749999998827
# Episode#:435 reward:95.0 best_reward:1099.0 eps:0.6476249999998823
# Episode#:436 reward:-910.0 best_reward:1099.0 eps:0.6463749999998819
# Episode#:437 reward:-904.0 best_reward:1099.0 eps:0.6458749999998817
# Episode#:438 reward:1095.0 best_reward:1099.0 eps:0.6446249999998813
# Episode#:439 reward:90.0 best_reward:1099.0 eps:0.6433749999998809
# Episode#:440 reward:-903.0 best_reward:1099.0 eps:0.6423749999998806
# Episode#:441 reward:-902.0 best_reward:1099.0 eps:0.6421249999998805
# Episode#:442 reward:90.0 best_reward:1099.0 eps:0.6408749999998801
# Episode#:443 reward:-906.0 best_reward:1099.0 eps:0.6401249999998798
# Episode#:444 reward:95.0 best_reward:1099.0 eps:0.6388749999998794
# Episode#:445 reward:999.0 best_reward:1099.0 eps:0.6381249999998792
# Episode#:446 reward:90.0 best_reward:1099.0 eps:0.6368749999998787
# Episode#:447 reward:-908.0 best_reward:1099.0 eps:0.6358749999998784
# Episode#:448 reward:-998.0 best_reward:1099.0 eps:0.6354999999998783
# Episode#:449 reward:1000.0 best_reward:1099.0 eps:0.6348749999998781
# Episode#:450 reward:1096.0 best_reward:1099.0 eps:0.6337499999998777
# Episode#:451 reward:90.0 best_reward:1099.0 eps:0.6324999999998773
# Episode#:452 reward:1095.0 best_reward:1099.0 eps:0.6312499999998769
# Episode#:453 reward:90.0 best_reward:1099.0 eps:0.6299999999998764
# Episode#:454 reward:-906.0 best_reward:1099.0 eps:0.6292499999998762
# Episode#:455 reward:-906.0 best_reward:1099.0 eps:0.6284999999998759
# Episode#:456 reward:-905.0 best_reward:1099.0 eps:0.6278749999998757
# Episode#:457 reward:-903.0 best_reward:1099.0 eps:0.6274999999998756
# Episode#:458 reward:90.0 best_reward:1099.0 eps:0.6262499999998752
# Episode#:459 reward:90.0 best_reward:1099.0 eps:0.6249999999998748
# Episode#:460 reward:-905.0 best_reward:1099.0 eps:0.6237499999998743
# Episode#:461 reward:-907.0 best_reward:1099.0 eps:0.6228749999998741
# Episode#:462 reward:-909.0 best_reward:1099.0 eps:0.6217499999998737
# Episode#:463 reward:-906.0 best_reward:1099.0 eps:0.6209999999998734
# Episode#:464 reward:-997.0 best_reward:1099.0 eps:0.6207499999998733
# Episode#:465 reward:95.0 best_reward:1099.0 eps:0.6194999999998729
# Episode#:466 reward:95.0 best_reward:1099.0 eps:0.6182499999998725
# Episode#:467 reward:-997.0 best_reward:1099.0 eps:0.6179999999998724
# Episode#:468 reward:-903.0 best_reward:1099.0 eps:0.6176249999998723
# Episode#:469 reward:-903.0 best_reward:1099.0 eps:0.6172499999998722
# Episode#:470 reward:-904.0 best_reward:1099.0 eps:0.616749999999872
# Episode#:471 reward:-997.0 best_reward:1099.0 eps:0.6164999999998719
# Episode#:472 reward:95.0 best_reward:1099.0 eps:0.6152499999998715
# Episode#:473 reward:90.0 best_reward:1099.0 eps:0.6139999999998711
# Episode#:474 reward:1000.0 best_reward:1099.0 eps:0.6133749999998709
# Episode#:475 reward:997.0 best_reward:1099.0 eps:0.6123749999998706
# Episode#:476 reward:1001.0 best_reward:1099.0 eps:0.6118749999998704
# Episode#:477 reward:1096.0 best_reward:1099.0 eps:0.61074999999987
# Episode#:478 reward:1000.0 best_reward:1099.0 eps:0.6101249999998698
# Episode#:479 reward:1002.0 best_reward:1099.0 eps:0.6097499999998697
# Episode#:480 reward:1099.0 best_reward:1099.0 eps:0.6089999999998694
# Episode#:481 reward:95.0 best_reward:1099.0 eps:0.607749999999869
# Episode#:482 reward:1002.0 best_reward:1099.0 eps:0.6073749999998689
# Episode#:483 reward:-903.0 best_reward:1099.0 eps:0.6069999999998688
# Episode#:484 reward:1097.0 best_reward:1099.0 eps:0.6059999999998684
# Episode#:485 reward:1099.0 best_reward:1099.0 eps:0.6052499999998682
# Episode#:486 reward:95.0 best_reward:1099.0 eps:0.6039999999998678
# Episode#:487 reward:-901.0 best_reward:1099.0 eps:0.6032499999998675
# Episode#:488 reward:1100.0 best_reward:1100.0 eps:0.6026249999998673
# Episode#:489 reward:1000.0 best_reward:1100.0 eps:0.6019999999998671
# Episode#:490 reward:1000.0 best_reward:1100.0 eps:0.6013749999998669
# Episode#:491 reward:95.0 best_reward:1100.0 eps:0.6001249999998665
# Episode#:492 reward:1099.0 best_reward:1100.0 eps:0.5993749999998662
# Episode#:493 reward:1100.0 best_reward:1100.0 eps:0.598749999999866
# Episode#:494 reward:1000.0 best_reward:1100.0 eps:0.5981249999998658
# Episode#:495 reward:-997.0 best_reward:1100.0 eps:0.5978749999998657
# Episode#:496 reward:-998.0 best_reward:1100.0 eps:0.5974999999998656
# Episode#:497 reward:-997.0 best_reward:1100.0 eps:0.5972499999998655
# Episode#:498 reward:-903.0 best_reward:1100.0 eps:0.5968749999998654
# Episode#:499 reward:1097.0 best_reward:1100.0 eps:0.595874999999865
# Episode#:500 reward:1100.0 best_reward:1100.0 eps:0.5952499999998648
# Episode#:501 reward:-5.0 best_reward:1100.0 eps:0.5939999999998644
# Episode#:502 reward:-903.0 best_reward:1100.0 eps:0.5936249999998643
# Episode#:503 reward:999.0 best_reward:1100.0 eps:0.592874999999864
# Episode#:504 reward:-905.0 best_reward:1100.0 eps:0.5922499999998638
# Episode#:505 reward:-903.0 best_reward:1100.0 eps:0.5918749999998637
# Episode#:506 reward:-902.0 best_reward:1100.0 eps:0.5916249999998636
# Episode#:507 reward:95.0 best_reward:1100.0 eps:0.5903749999998632
# Episode#:508 reward:1096.0 best_reward:1100.0 eps:0.5892499999998628
# Episode#:509 reward:1096.0 best_reward:1100.0 eps:0.5881249999998625
# Episode#:510 reward:-900.0 best_reward:1100.0 eps:0.5874999999998622
# Episode#:511 reward:1098.0 best_reward:1100.0 eps:0.586624999999862
# Episode#:512 reward:1098.0 best_reward:1100.0 eps:0.5857499999998617
# Episode#:513 reward:-902.0 best_reward:1100.0 eps:0.5854999999998616
# Episode#:514 reward:1099.0 best_reward:1100.0 eps:0.5847499999998613
# Episode#:515 reward:-903.0 best_reward:1100.0 eps:0.5843749999998612
# Episode#:516 reward:1100.0 best_reward:1100.0 eps:0.583749999999861
# Episode#:517 reward:1099.0 best_reward:1100.0 eps:0.5829999999998607
# Episode#:518 reward:1098.0 best_reward:1100.0 eps:0.5821249999998604
# Episode#:519 reward:-904.0 best_reward:1100.0 eps:0.5816249999998603
# Episode#:520 reward:-999.0 best_reward:1100.0 eps:0.5811249999998601
# Episode#:521 reward:-902.0 best_reward:1100.0 eps:0.58087499999986
# Episode#:522 reward:1095.0 best_reward:1100.0 eps:0.5796249999998596
# Episode#:523 reward:1100.0 best_reward:1100.0 eps:0.5789999999998594
# Episode#:524 reward:-902.0 best_reward:1100.0 eps:0.5787499999998593
# Episode#:525 reward:999.0 best_reward:1100.0 eps:0.5779999999998591
# Episode#:526 reward:1099.0 best_reward:1100.0 eps:0.5772499999998588
# Episode#:527 reward:1095.0 best_reward:1100.0 eps:0.5759999999998584
# Episode#:528 reward:1098.0 best_reward:1100.0 eps:0.5751249999998581
# Episode#:529 reward:95.0 best_reward:1100.0 eps:0.5738749999998577
# Episode#:530 reward:-903.0 best_reward:1100.0 eps:0.5734999999998576
# Episode#:531 reward:1097.0 best_reward:1100.0 eps:0.5724999999998572
# Episode#:532 reward:1100.0 best_reward:1100.0 eps:0.571874999999857
# Episode#:533 reward:-900.0 best_reward:1100.0 eps:0.5712499999998568
# Episode#:534 reward:-899.0 best_reward:1100.0 eps:0.5707499999998566
# Episode#:535 reward:-1000.0 best_reward:1100.0 eps:0.5701249999998564
# Episode#:536 reward:1097.0 best_reward:1100.0 eps:0.5691249999998561
# Episode#:537 reward:1000.0 best_reward:1100.0 eps:0.5684999999998559
# Episode#:538 reward:-905.0 best_reward:1100.0 eps:0.5678749999998557
# Episode#:539 reward:-904.0 best_reward:1100.0 eps:0.5673749999998555
# Episode#:540 reward:-903.0 best_reward:1100.0 eps:0.5669999999998554
# Episode#:541 reward:95.0 best_reward:1100.0 eps:0.565749999999855
# Episode#:542 reward:95.0 best_reward:1100.0 eps:0.5644999999998546
# Episode#:543 reward:-900.0 best_reward:1100.0 eps:0.5638749999998544
# Episode#:544 reward:-902.0 best_reward:1100.0 eps:0.5636249999998543
# Episode#:545 reward:-899.0 best_reward:1100.0 eps:0.5631249999998541
# Episode#:546 reward:1098.0 best_reward:1100.0 eps:0.5622499999998538
# Episode#:547 reward:-902.0 best_reward:1100.0 eps:0.5613749999998535
# Episode#:548 reward:95.0 best_reward:1100.0 eps:0.5601249999998531
# Episode#:549 reward:-902.0 best_reward:1100.0 eps:0.5592499999998528
# Episode#:550 reward:1099.0 best_reward:1100.0 eps:0.5584999999998526
# Episode#:551 reward:-902.0 best_reward:1100.0 eps:0.5576249999998523
# Episode#:552 reward:1098.0 best_reward:1100.0 eps:0.556749999999852
# Episode#:553 reward:1099.0 best_reward:1100.0 eps:0.5559999999998517
# Episode#:554 reward:95.0 best_reward:1100.0 eps:0.5547499999998513
# Episode#:555 reward:-1002.0 best_reward:1100.0 eps:0.553874999999851
# Episode#:556 reward:-905.0 best_reward:1100.0 eps:0.5526249999998506
# Episode#:557 reward:1001.0 best_reward:1100.0 eps:0.5521249999998504
# Episode#:558 reward:-903.0 best_reward:1100.0 eps:0.5511249999998501
# Episode#:559 reward:-909.0 best_reward:1100.0 eps:0.5499999999998497
# Episode#:560 reward:1099.0 best_reward:1100.0 eps:0.5492499999998495
# Episode#:561 reward:-904.0 best_reward:1100.0 eps:0.5487499999998493
# Episode#:562 reward:95.0 best_reward:1100.0 eps:0.5474999999998489
# Episode#:563 reward:-902.0 best_reward:1100.0 eps:0.5472499999998488
# Episode#:564 reward:1001.0 best_reward:1100.0 eps:0.5467499999998486
# Episode#:565 reward:1097.0 best_reward:1100.0 eps:0.5457499999998483
# Episode#:566 reward:-999.0 best_reward:1100.0 eps:0.5452499999998481
# Episode#:567 reward:-903.0 best_reward:1100.0 eps:0.544874999999848
# Episode#:568 reward:-902.0 best_reward:1100.0 eps:0.5439999999998477
# Episode#:569 reward:95.0 best_reward:1100.0 eps:0.5427499999998473
# Episode#:570 reward:1097.0 best_reward:1100.0 eps:0.541749999999847
# Episode#:571 reward:1099.0 best_reward:1100.0 eps:0.5409999999998467
# Episode#:572 reward:1099.0 best_reward:1100.0 eps:0.5402499999998465
# Episode#:573 reward:95.0 best_reward:1100.0 eps:0.538999999999846
# Episode#:574 reward:-902.0 best_reward:1100.0 eps:0.538749999999846
# Episode#:575 reward:-901.0 best_reward:1100.0 eps:0.5379999999998457
# Episode#:576 reward:1099.0 best_reward:1100.0 eps:0.5372499999998455
# Episode#:577 reward:1002.0 best_reward:1100.0 eps:0.5368749999998453
# Episode#:578 reward:1002.0 best_reward:1100.0 eps:0.5364999999998452
# Episode#:579 reward:-899.0 best_reward:1100.0 eps:0.535999999999845
# Episode#:580 reward:95.0 best_reward:1100.0 eps:0.5347499999998446
# Episode#:581 reward:1099.0 best_reward:1100.0 eps:0.5339999999998444
# Episode#:582 reward:1099.0 best_reward:1100.0 eps:0.5332499999998441
# Episode#:583 reward:95.0 best_reward:1100.0 eps:0.5319999999998437
# Episode#:584 reward:1002.0 best_reward:1100.0 eps:0.5316249999998436
# Episode#:585 reward:1099.0 best_reward:1100.0 eps:0.5308749999998433
# Episode#:586 reward:-907.0 best_reward:1100.0 eps:0.529999999999843
# Episode#:587 reward:-902.0 best_reward:1100.0 eps:0.5291249999998427
# Episode#:588 reward:1099.0 best_reward:1100.0 eps:0.5283749999998425
# Episode#:589 reward:-903.0 best_reward:1100.0 eps:0.5279999999998424
# Episode#:590 reward:1100.0 best_reward:1100.0 eps:0.5273749999998422
# Episode#:591 reward:95.0 best_reward:1100.0 eps:0.5261249999998417
# Episode#:592 reward:-903.0 best_reward:1100.0 eps:0.5257499999998416
# Episode#:593 reward:95.0 best_reward:1100.0 eps:0.5244999999998412
# Episode#:594 reward:1098.0 best_reward:1100.0 eps:0.5236249999998409
# Episode#:595 reward:95.0 best_reward:1100.0 eps:0.5223749999998405
# Episode#:596 reward:-903.0 best_reward:1100.0 eps:0.5213749999998402
# Episode#:597 reward:1098.0 best_reward:1100.0 eps:0.5204999999998399
# Episode#:598 reward:1096.0 best_reward:1100.0 eps:0.5193749999998395
# Episode#:599 reward:1098.0 best_reward:1100.0 eps:0.5184999999998392
# Episode#:600 reward:1097.0 best_reward:1100.0 eps:0.5174999999998389
# Episode#:601 reward:-903.0 best_reward:1100.0 eps:0.5171249999998387
# Episode#:602 reward:-902.0 best_reward:1100.0 eps:0.5168749999998387
# Episode#:603 reward:1097.0 best_reward:1100.0 eps:0.5158749999998383
# Episode#:604 reward:1099.0 best_reward:1100.0 eps:0.5151249999998381
# Episode#:605 reward:1100.0 best_reward:1100.0 eps:0.5144999999998379
# Episode#:606 reward:-904.0 best_reward:1100.0 eps:0.5139999999998377
# Episode#:607 reward:1099.0 best_reward:1100.0 eps:0.5132499999998374
# Episode#:608 reward:1100.0 best_reward:1100.0 eps:0.5126249999998372
# Episode#:609 reward:90.0 best_reward:1100.0 eps:0.5113749999998368
# Episode#:610 reward:-998.0 best_reward:1100.0 eps:0.5109999999998367
# Episode#:611 reward:1099.0 best_reward:1100.0 eps:0.5102499999998364
# Episode#:612 reward:-903.0 best_reward:1100.0 eps:0.5092499999998361
# Episode#:613 reward:1097.0 best_reward:1100.0 eps:0.5082499999998358
# Episode#:614 reward:1099.0 best_reward:1100.0 eps:0.5074999999998355
# Episode#:615 reward:-902.0 best_reward:1100.0 eps:0.5072499999998354
# Episode#:616 reward:95.0 best_reward:1100.0 eps:0.505999999999835
# Episode#:617 reward:1098.0 best_reward:1100.0 eps:0.5051249999998347
# Episode#:618 reward:-899.0 best_reward:1100.0 eps:0.5046249999998346
# Episode#:619 reward:-902.0 best_reward:1100.0 eps:0.5043749999998345
# Episode#:620 reward:-997.0 best_reward:1100.0 eps:0.5041249999998344
# Episode#:621 reward:-904.0 best_reward:1100.0 eps:0.5036249999998342
# Episode#:622 reward:95.0 best_reward:1100.0 eps:0.5023749999998338
# Episode#:623 reward:1096.0 best_reward:1100.0 eps:0.5012499999998334
# Episode#:624 reward:1099.0 best_reward:1100.0 eps:0.5004999999998332
# Episode#:625 reward:1098.0 best_reward:1100.0 eps:0.4996249999998331
# Episode#:626 reward:-902.0 best_reward:1100.0 eps:0.49937499999983315
# Episode#:627 reward:1100.0 best_reward:1100.0 eps:0.4987499999998332
# Episode#:628 reward:1002.0 best_reward:1100.0 eps:0.49837499999983326
# Episode#:629 reward:1097.0 best_reward:1100.0 eps:0.49737499999983337
# Episode#:630 reward:-903.0 best_reward:1100.0 eps:0.4969999999998334
# Episode#:631 reward:1096.0 best_reward:1100.0 eps:0.49587499999983353
# Episode#:632 reward:-902.0 best_reward:1100.0 eps:0.49562499999983356
# Episode#:633 reward:1000.0 best_reward:1100.0 eps:0.49499999999983363
# Episode#:634 reward:1100.0 best_reward:1100.0 eps:0.4943749999998337
# Episode#:635 reward:1001.0 best_reward:1100.0 eps:0.49387499999983375
# Episode#:636 reward:1098.0 best_reward:1100.0 eps:0.49299999999983385
# Episode#:637 reward:-902.0 best_reward:1100.0 eps:0.4927499999998339
# Episode#:638 reward:1098.0 best_reward:1100.0 eps:0.491874999999834
# Episode#:639 reward:95.0 best_reward:1100.0 eps:0.4906249999998341
# Episode#:640 reward:95.0 best_reward:1100.0 eps:0.48937499999983425
# Episode#:641 reward:1099.0 best_reward:1100.0 eps:0.48862499999983433
# Episode#:642 reward:1098.0 best_reward:1100.0 eps:0.4877499999998344
# Episode#:643 reward:1096.0 best_reward:1100.0 eps:0.48662499999983455
# Episode#:644 reward:-902.0 best_reward:1100.0 eps:0.4863749999998346
# Episode#:645 reward:95.0 best_reward:1100.0 eps:0.4851249999998347
# Episode#:646 reward:1099.0 best_reward:1100.0 eps:0.4843749999998348
# Episode#:647 reward:1097.0 best_reward:1100.0 eps:0.4833749999998349
# Episode#:648 reward:95.0 best_reward:1100.0 eps:0.48212499999983505
# Episode#:649 reward:1098.0 best_reward:1100.0 eps:0.48124999999983514
# Episode#:650 reward:1100.0 best_reward:1100.0 eps:0.4806249999998352
# Episode#:651 reward:1099.0 best_reward:1100.0 eps:0.4798749999998353
# Episode#:652 reward:1097.0 best_reward:1100.0 eps:0.4788749999998354
# Episode#:653 reward:-902.0 best_reward:1100.0 eps:0.4779999999998355
# Episode#:654 reward:95.0 best_reward:1100.0 eps:0.47674999999983564
# Episode#:655 reward:1098.0 best_reward:1100.0 eps:0.47587499999983573
# Episode#:656 reward:1097.0 best_reward:1100.0 eps:0.47487499999983585
# Episode#:657 reward:1095.0 best_reward:1100.0 eps:0.473624999999836
# Episode#:658 reward:-997.0 best_reward:1100.0 eps:0.473374999999836
# Episode#:659 reward:-902.0 best_reward:1100.0 eps:0.4724999999998361
# Episode#:660 reward:1002.0 best_reward:1100.0 eps:0.47212499999983615
# Episode#:661 reward:1098.0 best_reward:1100.0 eps:0.47124999999983624
# Episode#:662 reward:1099.0 best_reward:1100.0 eps:0.4704999999998363
# Episode#:663 reward:1100.0 best_reward:1100.0 eps:0.4698749999998364
# Episode#:664 reward:-899.0 best_reward:1100.0 eps:0.46937499999983645
# Episode#:665 reward:-904.0 best_reward:1100.0 eps:0.4688749999998365
# Episode#:666 reward:-903.0 best_reward:1100.0 eps:0.46849999999983655
# Episode#:667 reward:1095.0 best_reward:1100.0 eps:0.4672499999998367
# Episode#:668 reward:-902.0 best_reward:1100.0 eps:0.4669999999998367
# Episode#:669 reward:1100.0 best_reward:1100.0 eps:0.4663749999998368
# Episode#:670 reward:1099.0 best_reward:1100.0 eps:0.46562499999983686
# Episode#:671 reward:1100.0 best_reward:1100.0 eps:0.46499999999983693
# Episode#:672 reward:-902.0 best_reward:1100.0 eps:0.46474999999983696
# Episode#:673 reward:-903.0 best_reward:1100.0 eps:0.46374999999983707
# Episode#:674 reward:1095.0 best_reward:1100.0 eps:0.4624999999998372
# Episode#:675 reward:1100.0 best_reward:1100.0 eps:0.4618749999998373
# Episode#:676 reward:1098.0 best_reward:1100.0 eps:0.4609999999998374
# Episode#:677 reward:1097.0 best_reward:1100.0 eps:0.4599999999998375
# Episode#:678 reward:1100.0 best_reward:1100.0 eps:0.45937499999983755
# Episode#:679 reward:95.0 best_reward:1100.0 eps:0.4581249999998377
# Episode#:680 reward:-904.0 best_reward:1100.0 eps:0.45762499999983774
# Episode#:681 reward:95.0 best_reward:1100.0 eps:0.4563749999998379
# Episode#:682 reward:95.0 best_reward:1100.0 eps:0.455124999999838
# Episode#:683 reward:1000.0 best_reward:1100.0 eps:0.4544999999998381
# Episode#:684 reward:1002.0 best_reward:1100.0 eps:0.45412499999983813
# Episode#:685 reward:-901.0 best_reward:1100.0 eps:0.4533749999998382
# Episode#:686 reward:-902.0 best_reward:1100.0 eps:0.45312499999983824
# Episode#:687 reward:1099.0 best_reward:1100.0 eps:0.4523749999998383
# Episode#:688 reward:1097.0 best_reward:1100.0 eps:0.45137499999983843
# Episode#:689 reward:1002.0 best_reward:1100.0 eps:0.4509999999998385
# Episode#:690 reward:-997.0 best_reward:1100.0 eps:0.4507499999998385
# Episode#:691 reward:1100.0 best_reward:1100.0 eps:0.45012499999983857
# Episode#:692 reward:-899.0 best_reward:1100.0 eps:0.4496249999998386
# Episode#:693 reward:-997.0 best_reward:1100.0 eps:0.44937499999983865
# Episode#:694 reward:-902.0 best_reward:1100.0 eps:0.4491249999998387
# Episode#:695 reward:1100.0 best_reward:1100.0 eps:0.44849999999983875
# Episode#:696 reward:1096.0 best_reward:1100.0 eps:0.4473749999998389
# Episode#:697 reward:1098.0 best_reward:1100.0 eps:0.44649999999983897
# Episode#:698 reward:1099.0 best_reward:1100.0 eps:0.44574999999983905
# Episode#:699 reward:-899.0 best_reward:1100.0 eps:0.4452499999998391
# Episode#:700 reward:-899.0 best_reward:1100.0 eps:0.44474999999983916
# Episode#:701 reward:-1001.0 best_reward:1100.0 eps:0.44399999999983925
# Episode#:702 reward:1100.0 best_reward:1100.0 eps:0.4433749999998393
# ...
# Episode#:769 reward:1099.0 best_reward:1100.0 eps:0.3962499999998445
# Episode#:770 reward:1098.0 best_reward:1100.0 eps:0.3953749999998446
# Episode#:771 reward:1097.0 best_reward:1100.0 eps:0.3943749999998447
# Episode#:772 reward:1100.0 best_reward:1100.0 eps:0.3937499999998448
# Episode#:773 reward:1099.0 best_reward:1100.0 eps:0.39299999999984486
# Episode#:774 reward:-899.0 best_reward:1100.0 eps:0.3924999999998449
# Episode#:775 reward:1098.0 best_reward:1100.0 eps:0.391624999999845
# Episode#:776 reward:1100.0 best_reward:1100.0 eps:0.3909999999998451
# Episode#:777 reward:95.0 best_reward:1100.0 eps:0.3897499999998452
# Episode#:778 reward:-902.0 best_reward:1100.0 eps:0.38949999999984525
# Episode#:779 reward:1000.0 best_reward:1100.0 eps:0.3888749999998453
# Episode#:780 reward:95.0 best_reward:1100.0 eps:0.38762499999984545
# Episode#:781 reward:1099.0 best_reward:1100.0 eps:0.38687499999984554
# Episode#:782 reward:-997.0 best_reward:1100.0 eps:0.38662499999984556
# Episode#:783 reward:1098.0 best_reward:1100.0 eps:0.38574999999984566
# Episode#:784 reward:1001.0 best_reward:1100.0 eps:0.3852499999998457
# Episode#:785 reward:1097.0 best_reward:1100.0 eps:0.3842499999998458
# Episode#:786 reward:-903.0 best_reward:1100.0 eps:0.38387499999984587
# Episode#:787 reward:-902.0 best_reward:1100.0 eps:0.3836249999998459
# Episode#:788 reward:1098.0 best_reward:1100.0 eps:0.382749999999846
# Episode#:789 reward:1000.0 best_reward:1100.0 eps:0.38212499999984606
# Episode#:790 reward:1002.0 best_reward:1100.0 eps:0.3817499999998461
# Episode#:791 reward:1100.0 best_reward:1100.0 eps:0.38112499999984617
# Episode#:792 reward:-900.0 best_reward:1100.0 eps:0.38049999999984624
# Episode#:793 reward:-899.0 best_reward:1100.0 eps:0.3799999999998463
# Episode#:794 reward:-903.0 best_reward:1100.0 eps:0.37962499999984634
# Episode#:795 reward:95.0 best_reward:1100.0 eps:0.3783749999998465
# Episode#:796 reward:1099.0 best_reward:1100.0 eps:0.37762499999984656
# Episode#:797 reward:1100.0 best_reward:1100.0 eps:0.3769999999998466
# Episode#:798 reward:1001.0 best_reward:1100.0 eps:0.3764999999998467
# Episode#:799 reward:1000.0 best_reward:1100.0 eps:0.37587499999984675
# Episode#:800 reward:1099.0 best_reward:1100.0 eps:0.37512499999984683
# Episode#:801 reward:1099.0 best_reward:1100.0 eps:0.3743749999998469
# Episode#:802 reward:1001.0 best_reward:1100.0 eps:0.37387499999984697
# Episode#:803 reward:1100.0 best_reward:1100.0 eps:0.37324999999984704
# Episode#:804 reward:1097.0 best_reward:1100.0 eps:0.37224999999984715
# Episode#:805 reward:-899.0 best_reward:1100.0 eps:0.3717499999998472
# Episode#:806 reward:1099.0 best_reward:1100.0 eps:0.3709999999998473
# Episode#:807 reward:95.0 best_reward:1100.0 eps:0.3697499999998474
# Episode#:808 reward:1097.0 best_reward:1100.0 eps:0.36874999999984753
# Episode#:809 reward:-902.0 best_reward:1100.0 eps:0.36787499999984763
# Episode#:810 reward:1098.0 best_reward:1100.0 eps:0.3669999999998477
# Episode#:811 reward:1097.0 best_reward:1100.0 eps:0.36599999999984784
# Episode#:812 reward:1100.0 best_reward:1100.0 eps:0.3653749999998479
# Episode#:813 reward:1099.0 best_reward:1100.0 eps:0.364624999999848
# Episode#:814 reward:1002.0 best_reward:1100.0 eps:0.36424999999984803
# Episode#:815 reward:95.0 best_reward:1100.0 eps:0.36299999999984817
# Episode#:816 reward:-901.0 best_reward:1100.0 eps:0.36224999999984825
# Episode#:817 reward:-901.0 best_reward:1100.0 eps:0.36149999999984833
# Episode#:818 reward:-997.0 best_reward:1100.0 eps:0.36124999999984836
# Episode#:819 reward:1098.0 best_reward:1100.0 eps:0.36037499999984846
# Episode#:820 reward:1100.0 best_reward:1100.0 eps:0.3597499999998485
# Episode#:821 reward:-901.0 best_reward:1100.0 eps:0.3589999999998486
# Episode#:822 reward:1100.0 best_reward:1100.0 eps:0.3583749999998487
# Episode#:823 reward:95.0 best_reward:1100.0 eps:0.3571249999998488
# Episode#:824 reward:1096.0 best_reward:1100.0 eps:0.35599999999984894
# Episode#:825 reward:1100.0 best_reward:1100.0 eps:0.355374999999849
# Episode#:826 reward:1098.0 best_reward:1100.0 eps:0.3544999999998491
# Episode#:827 reward:-902.0 best_reward:1100.0 eps:0.35424999999984913
# Episode#:828 reward:1099.0 best_reward:1100.0 eps:0.3534999999998492
# Episode#:829 reward:1100.0 best_reward:1100.0 eps:0.3528749999998493
# Episode#:830 reward:-902.0 best_reward:1100.0 eps:0.3526249999998493
# Episode#:831 reward:1099.0 best_reward:1100.0 eps:0.3518749999998494
# Episode#:832 reward:1098.0 best_reward:1100.0 eps:0.3509999999998495
# Episode#:833 reward:1100.0 best_reward:1100.0 eps:0.35037499999984956
# Episode#:834 reward:-902.0 best_reward:1100.0 eps:0.3501249999998496
# Episode#:835 reward:1099.0 best_reward:1100.0 eps:0.34937499999984967
# Episode#:836 reward:1099.0 best_reward:1100.0 eps:0.34862499999984975
# Episode#:837 reward:1097.0 best_reward:1100.0 eps:0.34762499999984986
# Episode#:838 reward:1100.0 best_reward:1100.0 eps:0.34699999999984993
# Episode#:839 reward:1100.0 best_reward:1100.0 eps:0.34637499999985
# Episode#:840 reward:1095.0 best_reward:1100.0 eps:0.34512499999985013
# Episode#:841 reward:95.0 best_reward:1100.0 eps:0.3438749999998503
# Episode#:842 reward:95.0 best_reward:1100.0 eps:0.3426249999998504
# Episode#:843 reward:1002.0 best_reward:1100.0 eps:0.34224999999985045
# Episode#:844 reward:1098.0 best_reward:1100.0 eps:0.34137499999985055
# Episode#:845 reward:1095.0 best_reward:1100.0 eps:0.3401249999998507
# Episode#:846 reward:1002.0 best_reward:1100.0 eps:0.3397499999998507
# Episode#:847 reward:1099.0 best_reward:1100.0 eps:0.3389999999998508
# Episode#:848 reward:1098.0 best_reward:1100.0 eps:0.3381249999998509
# Episode#:849 reward:1097.0 best_reward:1100.0 eps:0.337124999999851
# Episode#:850 reward:-904.0 best_reward:1100.0 eps:0.33662499999985107
# Episode#:851 reward:1099.0 best_reward:1100.0 eps:0.33587499999985115
# Episode#:852 reward:-903.0 best_reward:1100.0 eps:0.33487499999985126
# Episode#:853 reward:1097.0 best_reward:1100.0 eps:0.3338749999998514
# Episode#:854 reward:95.0 best_reward:1100.0 eps:0.3326249999998515
# Episode#:855 reward:1096.0 best_reward:1100.0 eps:0.33149999999985164
# Episode#:856 reward:-902.0 best_reward:1100.0 eps:0.33124999999985166
# Episode#:857 reward:1096.0 best_reward:1100.0 eps:0.3301249999998518
# Episode#:858 reward:1099.0 best_reward:1100.0 eps:0.32937499999985187
# Episode#:859 reward:-900.0 best_reward:1100.0 eps:0.32874999999985194
# Episode#:860 reward:1100.0 best_reward:1100.0 eps:0.328124999999852
# Episode#:861 reward:1099.0 best_reward:1100.0 eps:0.3273749999998521
# Episode#:862 reward:1096.0 best_reward:1100.0 eps:0.3262499999998522
# Episode#:863 reward:-903.0 best_reward:1100.0 eps:0.32587499999985226
# Episode#:864 reward:95.0 best_reward:1100.0 eps:0.3246249999998524
# Episode#:865 reward:1099.0 best_reward:1100.0 eps:0.3238749999998525
# Episode#:866 reward:1096.0 best_reward:1100.0 eps:0.3227499999998526
# Episode#:867 reward:-902.0 best_reward:1100.0 eps:0.3224999999998526
# Episode#:868 reward:95.0 best_reward:1100.0 eps:0.32124999999985276
# Episode#:869 reward:1100.0 best_reward:1100.0 eps:0.32062499999985283
# Episode#:870 reward:-902.0 best_reward:1100.0 eps:0.32037499999985286
# Episode#:871 reward:1098.0 best_reward:1100.0 eps:0.31949999999985296
# Episode#:872 reward:1100.0 best_reward:1100.0 eps:0.318874999999853
# Episode#:873 reward:1001.0 best_reward:1100.0 eps:0.3183749999998531
# Episode#:874 reward:-902.0 best_reward:1100.0 eps:0.3181249999998531
# Episode#:875 reward:1002.0 best_reward:1100.0 eps:0.31774999999985315
# Episode#:876 reward:-904.0 best_reward:1100.0 eps:0.3172499999998532
# Episode#:877 reward:1099.0 best_reward:1100.0 eps:0.3164999999998533
# Episode#:878 reward:-997.0 best_reward:1100.0 eps:0.3162499999998533
# Episode#:879 reward:-998.0 best_reward:1100.0 eps:0.31587499999985336
# Episode#:880 reward:95.0 best_reward:1100.0 eps:0.3146249999998535
# Episode#:881 reward:1099.0 best_reward:1100.0 eps:0.3138749999998536
# Episode#:882 reward:1099.0 best_reward:1100.0 eps:0.31312499999985366
# Episode#:883 reward:1001.0 best_reward:1100.0 eps:0.3126249999998537
# Episode#:884 reward:1099.0 best_reward:1100.0 eps:0.3118749999998538
# Episode#:885 reward:1100.0 best_reward:1100.0 eps:0.31124999999985387
# Episode#:886 reward:1099.0 best_reward:1100.0 eps:0.31049999999985395
# Episode#:887 reward:1098.0 best_reward:1100.0 eps:0.30962499999985404
# Episode#:888 reward:-902.0 best_reward:1100.0 eps:0.3093749999998541
# Episode#:889 reward:-902.0 best_reward:1100.0 eps:0.3091249999998541
# Episode#:890 reward:1100.0 best_reward:1100.0 eps:0.30849999999985417
# Episode#:891 reward:1097.0 best_reward:1100.0 eps:0.3074999999998543
# Episode#:892 reward:1099.0 best_reward:1100.0 eps:0.30674999999985436
# Episode#:893 reward:1100.0 best_reward:1100.0 eps:0.30612499999985443
# Episode#:894 reward:1098.0 best_reward:1100.0 eps:0.3052499999998545
# Episode#:895 reward:1099.0 best_reward:1100.0 eps:0.3044999999998546
# Episode#:896 reward:1098.0 best_reward:1100.0 eps:0.3036249999998547
# Episode#:897 reward:1095.0 best_reward:1100.0 eps:0.30237499999985484
# Episode#:898 reward:1099.0 best_reward:1100.0 eps:0.3016249999998549
# Episode#:899 reward:1100.0 best_reward:1100.0 eps:0.300999999999855
# Episode#:900 reward:1099.0 best_reward:1100.0 eps:0.3002499999998551
# Episode#:901 reward:-903.0 best_reward:1100.0 eps:0.2992499999998552
# Episode#:902 reward:95.0 best_reward:1100.0 eps:0.2979999999998553
# Episode#:903 reward:1099.0 best_reward:1100.0 eps:0.2972499999998554
# Episode#:904 reward:-904.0 best_reward:1100.0 eps:0.29674999999985546
# Episode#:905 reward:1100.0 best_reward:1100.0 eps:0.29612499999985553
# Episode#:906 reward:1100.0 best_reward:1100.0 eps:0.2954999999998556
# Episode#:907 reward:1097.0 best_reward:1100.0 eps:0.2944999999998557
# Episode#:908 reward:1100.0 best_reward:1100.0 eps:0.2938749999998558
# Episode#:909 reward:-902.0 best_reward:1100.0 eps:0.2936249999998558
# Episode#:910 reward:1100.0 best_reward:1100.0 eps:0.2929999999998559
# Episode#:911 reward:95.0 best_reward:1100.0 eps:0.291749999999856
# Episode#:912 reward:999.0 best_reward:1100.0 eps:0.2909999999998561
# Episode#:913 reward:1099.0 best_reward:1100.0 eps:0.2902499999998562
# Episode#:914 reward:1097.0 best_reward:1100.0 eps:0.2892499999998563
# Episode#:915 reward:1100.0 best_reward:1100.0 eps:0.28862499999985636
# Episode#:916 reward:95.0 best_reward:1100.0 eps:0.2873749999998565
# Episode#:917 reward:1099.0 best_reward:1100.0 eps:0.2866249999998566
# Episode#:918 reward:95.0 best_reward:1100.0 eps:0.2853749999998567
# Episode#:919 reward:95.0 best_reward:1100.0 eps:0.28412499999985685
# Episode#:920 reward:1100.0 best_reward:1100.0 eps:0.2834999999998569
# Episode#:921 reward:1097.0 best_reward:1100.0 eps:0.28249999999985703
# Episode#:922 reward:1100.0 best_reward:1100.0 eps:0.2818749999998571
# Episode#:923 reward:1098.0 best_reward:1100.0 eps:0.2809999999998572
# Episode#:924 reward:1100.0 best_reward:1100.0 eps:0.28037499999985727
# Episode#:925 reward:1095.0 best_reward:1100.0 eps:0.2791249999998574
# Episode#:926 reward:1100.0 best_reward:1100.0 eps:0.2784999999998575
# Episode#:927 reward:1097.0 best_reward:1100.0 eps:0.2774999999998576
# Episode#:928 reward:-899.0 best_reward:1100.0 eps:0.27699999999985764
# Episode#:929 reward:1098.0 best_reward:1100.0 eps:0.27612499999985773
# Episode#:930 reward:1096.0 best_reward:1100.0 eps:0.27499999999985786
# Episode#:931 reward:1100.0 best_reward:1100.0 eps:0.2743749999998579
# Episode#:932 reward:1100.0 best_reward:1100.0 eps:0.273749999999858
# Episode#:933 reward:1100.0 best_reward:1100.0 eps:0.27312499999985806
# Episode#:934 reward:1099.0 best_reward:1100.0 eps:0.27237499999985815
# Episode#:935 reward:1100.0 best_reward:1100.0 eps:0.2717499999998582
# Episode#:936 reward:1100.0 best_reward:1100.0 eps:0.2711249999998583
# Episode#:937 reward:-997.0 best_reward:1100.0 eps:0.2708749999998583
# Episode#:938 reward:1100.0 best_reward:1100.0 eps:0.2702499999998584
# Episode#:939 reward:1098.0 best_reward:1100.0 eps:0.2693749999998585
# Episode#:940 reward:1098.0 best_reward:1100.0 eps:0.2684999999998586
# Episode#:941 reward:1099.0 best_reward:1100.0 eps:0.26774999999985866
# Episode#:942 reward:1100.0 best_reward:1100.0 eps:0.2671249999998587
# Episode#:943 reward:1097.0 best_reward:1100.0 eps:0.26612499999985884
# Episode#:944 reward:1098.0 best_reward:1100.0 eps:0.26524999999985893
# Episode#:945 reward:1100.0 best_reward:1100.0 eps:0.264624999999859
# Episode#:946 reward:95.0 best_reward:1100.0 eps:0.26337499999985914
# Episode#:947 reward:-899.0 best_reward:1100.0 eps:0.2628749999998592
# Episode#:948 reward:1098.0 best_reward:1100.0 eps:0.2619999999998593
# Episode#:949 reward:-903.0 best_reward:1100.0 eps:0.26162499999985933
# Episode#:950 reward:-902.0 best_reward:1100.0 eps:0.26137499999985936
# Episode#:951 reward:-902.0 best_reward:1100.0 eps:0.2611249999998594
# Episode#:952 reward:1100.0 best_reward:1100.0 eps:0.26049999999985946
# Episode#:953 reward:1099.0 best_reward:1100.0 eps:0.25974999999985954
# Episode#:954 reward:1097.0 best_reward:1100.0 eps:0.25874999999985965
# Episode#:955 reward:95.0 best_reward:1100.0 eps:0.2574999999998598
# Episode#:956 reward:1096.0 best_reward:1100.0 eps:0.2563749999998599
# Episode#:957 reward:-899.0 best_reward:1100.0 eps:0.25587499999985996
# Episode#:958 reward:1099.0 best_reward:1100.0 eps:0.25512499999986005
# Episode#:959 reward:1100.0 best_reward:1100.0 eps:0.2544999999998601
# Episode#:960 reward:1100.0 best_reward:1100.0 eps:0.2538749999998602
# Episode#:961 reward:1100.0 best_reward:1100.0 eps:0.25324999999986025
# Episode#:962 reward:-902.0 best_reward:1100.0 eps:0.25237499999986035
# Episode#:963 reward:1100.0 best_reward:1100.0 eps:0.2517499999998604
# Episode#:964 reward:1100.0 best_reward:1100.0 eps:0.2511249999998605
# Episode#:965 reward:1098.0 best_reward:1100.0 eps:0.2502499999998606
# Episode#:966 reward:-901.0 best_reward:1100.0 eps:0.24949999999986067
# Episode#:967 reward:1100.0 best_reward:1100.0 eps:0.24887499999986074
# Episode#:968 reward:1100.0 best_reward:1100.0 eps:0.2482499999998608
# Episode#:969 reward:1099.0 best_reward:1100.0 eps:0.2474999999998609
# Episode#:970 reward:1100.0 best_reward:1100.0 eps:0.24687499999986096
# Episode#:971 reward:1001.0 best_reward:1100.0 eps:0.246374999999861
# Episode#:972 reward:1098.0 best_reward:1100.0 eps:0.2454999999998611
# Episode#:973 reward:-902.0 best_reward:1100.0 eps:0.24524999999986113
# Episode#:974 reward:1098.0 best_reward:1100.0 eps:0.24437499999986123
# Episode#:975 reward:1100.0 best_reward:1100.0 eps:0.2437499999998613
# Episode#:976 reward:1100.0 best_reward:1100.0 eps:0.24312499999986137
# Episode#:977 reward:1099.0 best_reward:1100.0 eps:0.24237499999986145
# Episode#:978 reward:1100.0 best_reward:1100.0 eps:0.24174999999986152
# Episode#:979 reward:1100.0 best_reward:1100.0 eps:0.2411249999998616
# Episode#:980 reward:1098.0 best_reward:1100.0 eps:0.24024999999986169
# Episode#:981 reward:-904.0 best_reward:1100.0 eps:0.23974999999986174
# Episode#:982 reward:1100.0 best_reward:1100.0 eps:0.2391249999998618
# Episode#:983 reward:-903.0 best_reward:1100.0 eps:0.23874999999986185
# Episode#:984 reward:1100.0 best_reward:1100.0 eps:0.23812499999986192
# Episode#:985 reward:-899.0 best_reward:1100.0 eps:0.23762499999986197
# Episode#:986 reward:-904.0 best_reward:1100.0 eps:0.23712499999986203
# Episode#:987 reward:1000.0 best_reward:1100.0 eps:0.2364999999998621
# Episode#:988 reward:-902.0 best_reward:1100.0 eps:0.23624999999986213
# Episode#:989 reward:-902.0 best_reward:1100.0 eps:0.23599999999986215
# Episode#:990 reward:1100.0 best_reward:1100.0 eps:0.23537499999986222
# Episode#:991 reward:1100.0 best_reward:1100.0 eps:0.2347499999998623
# Episode#:992 reward:1100.0 best_reward:1100.0 eps:0.23412499999986236
# Episode#:993 reward:1100.0 best_reward:1100.0 eps:0.23349999999986243
# Episode#:994 reward:-899.0 best_reward:1100.0 eps:0.23299999999986248
# Episode#:995 reward:1099.0 best_reward:1100.0 eps:0.23224999999986257
# Episode#:996 reward:1096.0 best_reward:1100.0 eps:0.2311249999998627
# Episode#:997 reward:1097.0 best_reward:1100.0 eps:0.2301249999998628
# Episode#:998 reward:-901.0 best_reward:1100.0 eps:0.22937499999986288
# Episode#:999 reward:1098.0 best_reward:1100.0 eps:0.22849999999986298

# %%
learned_policy
# Out:
# array([0, 3, 0, 3, 2, 2, 3, 3, 0, 0, 0, 3])

# %% [markdown]
# ### Teste

# %%
# Função responsável por testar a política aprendida a partir da realização da ação
# de acordo com o estado atual e verificação do ambiente, do estado e da pontuação
# geral obtida
def test(agent: Agent, env, policy):
    done = False
    obs = env.reset()
    total_reward = 0.0
    steps = 0
    actions = ['DOWN', 'LEFT', 'UP', 'RIGHT']
    env.render() 
    while not done:
        action = policy[obs]
        print(actions[action])
        next_obs, reward, done, info = env.step(action)   
        env.render()     
        obs = next_obs
        total_reward += reward
        # print('total_reward: ', total_reward)
        steps += 1
        if steps > 10:
            break
    return total_reward

# %%
# Teste a partir da política obtida
total = test(rat_agent, env, learned_policy)

print('TOTAL>>>>>>>', total)
# Out:
# ['R', 5, 0]
# [100, -1000, 1000]
# DOWN
# [0, 5, 0]
# ['R', -1000, 1000]
# UP
# ['R', 5, 0]
# [0, -1000, 1000]
# RIGHT
# [0, 'R', 0]
# [0, -1000, 1000]
# RIGHT
# [0, 0, 'R']
# [0, -1000, 1000]
# DOWN
# [0, 0, 0]
# [0, -1000, 'R']
# TOTAL>>>>>>> 1100.0

# %% [markdown]
# A partir do output acima, verificamos que o caminho seguido pelo rato foi DOWN-UP-RIGHT-RIGHT-DOWN, que representa o caminho em que ele pega todos os queijos.
